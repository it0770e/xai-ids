# %% [markdown]
# <a href="https://colab.research.google.com/github/it0770e/xai-ids/blob/main/Notebook01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# CELL 1
from google.colab import drive
drive.mount('/content/drive')

import os
BASE = '/content/drive/MyDrive/xai-ids'
for folder in ['data/raw','data/processed','results/figures','results/metrics','results/models','logs']:
    os.makedirs(f'{BASE}/{folder}', exist_ok=True)
print('✅ Drive mounted, folders created')
# Out:
# Mounted at /content/drive
# ✅ Drive mounted, folders created

# %%
# CELL 2
# !pip install imbalanced-learn shap lime -q
print('✅ Packages installed')
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 11.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
# ✅ Packages installed

# %%
# CELL 3
import pandas as pd, numpy as np, sklearn, tensorflow as tf
import shap, lime, imblearn, matplotlib, seaborn, scipy

for lib, ver in [('pandas',pd.__version__),('numpy',np.__version__),
                 ('scikit-learn',sklearn.__version__),('tensorflow',tf.__version__),
                 ('shap',shap.__version__),('imbalanced-learn',imblearn.__version__)]:
    print(f'{lib:<20} {ver}')
print('✅ All imports OK')
# Out:
# pandas               2.2.2
# numpy                2.0.2
# scikit-learn         1.6.1
# tensorflow           2.19.0
# shap                 0.51.0
# imbalanced-learn     0.14.1
# ✅ All imports OK

# %%
# CELL 4
test_df = pd.DataFrame({'a':[1,2],'b':[3,4]})
test_df.to_csv(f'{BASE}/data/raw/test_data.csv', index=False)
import pandas as pd
assert pd.read_csv(f'{BASE}/data/raw/test_data.csv').shape == (2,2)
print('✅ Drive write/read test passed — ready for Notebook 02')
# Out:
# ✅ Drive write/read test passed — ready for Notebook 02
