# %%
# ============================================
# CELL 1: Mount Google Drive (for saving files)
# ============================================
from google.colab import drive
drive.mount('/content/drive')

# Create your project folders in Drive
import os

drive_path = '/content/drive/MyDrive/xai-ids/'
folders = [
    'data/raw',
    'data/processed',
    'results/figures',
    'results/metrics',
    'results/models',
    'logs'
]

for folder in folders:
    os.makedirs(drive_path + folder, exist_ok=True)

print("✅ Google Drive mounted and folders created!")
print(f"📁 Your project folder: {drive_path}")
# Out:
# Mounted at /content/drive
# ✅ Google Drive mounted and folders created!
# 📁 Your project folder: /content/drive/MyDrive/xai-ids/

# %%
# ============================================
# CELL 2: Test your setup
# ============================================
import pandas as pd
import numpy as np
import sklearn
import tensorflow as tf

print("🎉 All libraries imported successfully!")
print(f"Pandas version: {pd.__version__}")
print(f"NumPy version: {np.__version__}")
print(f"Scikit-learn version: {sklearn.__version__}")
print(f"TensorFlow version: {tf.__version__}")

# Create a simple test
print("\n📊 Creating sample data...")
data = {
    'feature1': [1, 2, 3, 4, 5],
    'feature2': [10, 20, 30, 40, 50],
    'label': [0, 0, 1, 1, 1]
}
df = pd.DataFrame(data)
print(df)

# Save to Drive
df.to_csv('/content/drive/MyDrive/xai-ids/data/raw/test_data.csv', index=False)
print("\n✅ Test data saved to Drive!")
# Out:
# 🎉 All libraries imported successfully!
# Pandas version: 2.2.2
# NumPy version: 2.0.2
# Scikit-learn version: 1.6.1
# TensorFlow version: 2.19.0
#
# 📊 Creating sample data...
#    feature1  feature2  label
# 0         1        10      0
# 1         2        20      0
# 2         3        30      1
# 3         4        40      1
# 4         5        50      1
#
# ✅ Test data saved to Drive!
